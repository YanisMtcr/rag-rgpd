# %% [markdown]
# # 03 - Gradio demo (local)
#
# Launches the Gradio interface with the frozen config (best embedder + best LLM + best prompt chosen from `02_experiments`).

# %%
import sys, os
os.chdir('..')
sys.path.insert(0, '.')

# %%
# runs the app (gradio served on localhost:7860)
# !python app.py
