# %% [markdown]
# # 03 - Demo Gradio (Colab)
#
# Lance l'interface Gradio avec la config figee (meilleur embedder + meilleur LLM + meilleur prompt determines par `02_experiments`).

# %%
# installation
# !pip install -q -r ../requirements.txt

# %%
# si tu utilises drive
# from google.colab import drive; drive.mount('/content/drive')
# %cd /content/drive/MyDrive/rag-rgpd

import sys, os
os.chdir('..')
sys.path.insert(0, '.')

# %%
# lance l'app (URL publique share valide 72h)
# !python app.py
